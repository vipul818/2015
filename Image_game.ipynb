# %% [markdown]
# <a href="https://colab.research.google.com/github/vipul818/2015/blob/master/Image_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
def rotate_image(image, angle):
  image_center = tuple(np.array(image.shape[1::-1]) / 2)
  rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
  result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
  return result
 
def sift(image):
  img1=cv2.imread(image)
  cv2_imshow(img1)
  img2=rotate_image(img1,34)


  # convert images to grayscale
  img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
  img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
  # create SIFT object
  sift = cv2.xfeatures2d.SIFT_create()
  # detect SIFT features in both images
  keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
  keypoints_2, descriptors_2 = sift.detectAndCompute(img2,None)
  #Now that we have keypoints and descriptors of both images, let's make a matcher to match the descriptors:

  # create feature matcher
  bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
  # match descriptors of both images
  matches = bf.match(descriptors_1,descriptors_2)
  #Let's sort the matches by distance and draw the first 50 matches:

  # sort matches by distance
  matches = sorted(matches, key = lambda x:x.distance)
  # draw first 50 matches
  matched_img = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:50], img2, flags=2)
  #Finally, showing and saving the image:

  # show the image
  cv2_imshow(matched_img)
  # save the image
  cv2.waitKey(0)
  cv2.destroyAllWindows()

# %%
sift("thumbnail.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x184 at 0x7F9148F59C50>
# <PIL.Image.Image image mode=RGB size=400x184 at 0x7F9148F59B50>

# %%
sift("thumbnail1.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x138 at 0x7F9148F59C90>
# <PIL.Image.Image image mode=RGB size=400x138 at 0x7F9148F59710>

# %%
sift("thumbnail2.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x174 at 0x7F9148F61C50>
# <PIL.Image.Image image mode=RGB size=400x174 at 0x7F9148F611D0>

# %%
sift("thumbnail3.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=185x200 at 0x7F9148F531D0>
# <PIL.Image.Image image mode=RGB size=370x200 at 0x7F9148F61D90>

# %%
sift("thumbnail4.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=185x200 at 0x7F9148F47210>
# <PIL.Image.Image image mode=RGB size=370x200 at 0x7F9148F47590>

# %%
sift("thumbnail5.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x121 at 0x7F9148F33E10>
# <PIL.Image.Image image mode=RGB size=400x121 at 0x7F9148F37E90>

# %%
sift("thumbnail6.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x175 at 0x7F9149FB2450>
# <PIL.Image.Image image mode=RGB size=400x175 at 0x7F9149FB2450>

# %%
sift("thumbnail7.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x108 at 0x7F9148F5E4D0>
# <PIL.Image.Image image mode=RGB size=400x108 at 0x7F9148F5E310>

# %%
sift("thumbnail8.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x134 at 0x7F9148EF9750>
# <PIL.Image.Image image mode=RGB size=400x134 at 0x7F9148EF9C90>

# %%
sift("thumbnail9.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x190 at 0x7F9149FB2410>
# <PIL.Image.Image image mode=RGB size=400x190 at 0x7F9149FB2410>
